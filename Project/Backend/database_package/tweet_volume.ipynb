# %%
import tweepy, os, pprint
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()

client = tweepy.Client(os.getenv("BEARER_TOKEN"))

# %%
volume = client.get_recent_tweets_count("aapl", granularity="day")
df = pd.DataFrame(volume.data)
df
# Out:
#                         end                     start  tweet_count
# 0  2022-10-11T00:00:00.000Z  2022-10-10T20:57:43.000Z          503
# 1  2022-10-12T00:00:00.000Z  2022-10-11T00:00:00.000Z         5415
# 2  2022-10-13T00:00:00.000Z  2022-10-12T00:00:00.000Z         5666
# 3  2022-10-14T00:00:00.000Z  2022-10-13T00:00:00.000Z         6649
# 4  2022-10-15T00:00:00.000Z  2022-10-14T00:00:00.000Z         6337
# 5  2022-10-16T00:00:00.000Z  2022-10-15T00:00:00.000Z         3107
# 6  2022-10-17T00:00:00.000Z  2022-10-16T00:00:00.000Z         3304
# 7  2022-10-17T20:57:43.000Z  2022-10-17T00:00:00.000Z         5510

# %%
df.plot.bar(x="end", y="tweet_count")
# Out:
# <AxesSubplot: xlabel='end'>
